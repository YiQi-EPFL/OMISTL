# %%
from model_train import train
from sampling import samping

# %%
samping(8,7)
# Out:
# 100%|██████████| 20000/20000 [37:35<00:00,  8.87it/s]

# %%
samping(8,8)
# Out:
# 100%|██████████| 20000/20000 [36:32<00:00,  9.12it/s]

# %%
for i in range(6,10):
    samping(6,i)
# Out:
# ...
# 100%|██████████| 20000/20000 [22:39<00:00, 14.71it/s]

# %%
train(8,8)
# Out:
# nubmber of strategies:1007
# n_obs: 8
# N: 8
# No existing model!
# loss:   2.4890031814575195,   acc:  0.46875
# loss:   1.885723352432251,   acc:  0.5
# Done with epoch 0 in 8.513172388076782s
# loss:   1.5297194719314575,   acc:  0.53125
# loss:   1.2204909324645996,   acc:  0.625
# Done with epoch 1 in 8.34448528289795s
# loss:   1.20735502243042,   acc:  0.75
# loss:   1.581028938293457,   acc:  0.59375
# Done with epoch 2 in 8.375606298446655s
# loss:   1.0236976146697998,   acc:  0.75
# loss:   1.7107198238372803,   acc:  0.5
# loss:   1.2425858974456787,   acc:  0.625
# Done with epoch 3 in 8.454567670822144s
# loss:   0.9587514400482178,   acc:  0.6875
# loss:   1.4228909015655518,   acc:  0.5625
# Done with epoch 4 in 8.344444751739502s
# loss:   0.684113621711731,   acc:  0.71875
# loss:   0.7398251891136169,   acc:  0.75
# Done with epoch 5 in 8.344504356384277s
# loss:   0.8227239847183228,   acc:  0.8125
# loss:   1.2635209560394287,   acc:  0.65625
# ...

# %%
train(8,7)
# Out:
# nubmber of strategies:936
# n_obs: 7
# N: 8
# No existing model!
# loss:   2.46636700630188,   acc:  0.46875
# Done with epoch 0 in 7.28186559677124s
# loss:   1.9833987951278687,   acc:  0.5
# loss:   1.4552034139633179,   acc:  0.6875
# Done with epoch 1 in 7.484911203384399s
# loss:   1.3840417861938477,   acc:  0.5625
# loss:   1.203862190246582,   acc:  0.6875
# Done with epoch 2 in 7.563242197036743s
# loss:   1.547253966331482,   acc:  0.53125
# loss:   1.4114793539047241,   acc:  0.59375
# Done with epoch 3 in 7.500505685806274s
# loss:   1.2399905920028687,   acc:  0.5625
# loss:   1.0273305177688599,   acc:  0.6875
# Done with epoch 4 in 7.532067537307739s
# loss:   0.775143027305603,   acc:  0.78125
# loss:   1.3075042963027954,   acc:  0.5625
# Done with epoch 5 in 7.531846523284912s
# loss:   1.164050817489624,   acc:  0.59375
# loss:   0.7512578964233398,   acc:  0.75
# Done with epoch 6 in 7.656913995742798s
# loss:   0.9530017375946045,   acc:  0.75
# ...

# %%
samping(8,6)
# Out:
# 100%|██████████| 20000/20000 [34:58<00:00,  9.53it/s]

# %%
train(8,6)
# Out:
# nubmber of strategies:940
# n_obs: 6
# N: 8
# No existing model!
# loss:   1.617571473121643,   acc:  0.5625
# Done with epoch 0 in 7.920830965042114s
# loss:   1.2229138612747192,   acc:  0.6875
# loss:   1.3480545282363892,   acc:  0.625
# Done with epoch 1 in 8.078751802444458s
# loss:   2.0614473819732666,   acc:  0.46875
# loss:   1.0402668714523315,   acc:  0.625
# Done with epoch 2 in 8.00064992904663s
# loss:   1.1264147758483887,   acc:  0.5625
# Done with epoch 3 in 7.969334363937378s
# loss:   1.42954683303833,   acc:  0.53125
# loss:   1.4533969163894653,   acc:  0.5
# Done with epoch 4 in 7.812978267669678s
# loss:   1.2509845495224,   acc:  0.625
# loss:   1.3770554065704346,   acc:  0.53125
# Done with epoch 5 in 7.8756372928619385s
# loss:   0.7753458023071289,   acc:  0.71875
# Done with epoch 6 in 7.769972324371338s
# loss:   1.091707706451416,   acc:  0.65625
# loss:   0.8036925792694092,   acc:  0.75
# Done with epoch 7 in 7.922461271286011s
# ...

# %%
for i in range(6,10):
    train(6,i)
# Out:
# nubmber of strategies:232
# n_obs: 6
# N: 6
# No existing model!
# loss:   2.04512619972229,   acc:  0.53125
# Done with epoch 0 in 6.328887224197388s
# loss:   1.0607190132141113,   acc:  0.65625
# loss:   0.9456515312194824,   acc:  0.75
# Done with epoch 1 in 6.391052484512329s
# loss:   0.6586141586303711,   acc:  0.8125
# loss:   0.5332329273223877,   acc:  0.875
# Done with epoch 2 in 6.563211679458618s
# loss:   0.8757990598678589,   acc:  0.78125
# Done with epoch 3 in 6.281735181808472s
# loss:   0.5026716589927673,   acc:  0.8125
# loss:   0.8985148668289185,   acc:  0.6875
# Done with epoch 4 in 6.360027551651001s
# loss:   0.46826866269111633,   acc:  0.84375
# loss:   0.5468817949295044,   acc:  0.78125
# Done with epoch 5 in 6.391324281692505s
# loss:   0.5057749152183533,   acc:  0.78125
# Done with epoch 6 in 6.313050746917725s
# loss:   0.6773581504821777,   acc:  0.75
# loss:   0.8192598819732666,   acc:  0.6875
# Done with epoch 7 in 6.813088655471802s
# ...
